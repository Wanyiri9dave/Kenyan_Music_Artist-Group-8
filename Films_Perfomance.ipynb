# %% [markdown]
# <a href="https://colab.research.google.com/github/Wanyiri9dave/Kenyan_Music_Artist-Group-8/blob/main/Films_Perfomance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***FILM PERFOMANCE ANALYSIS***
#
# ---

# %% [markdown]
# ![a68b17be-6311-4d99-a120-68d66b13162c.jpg](data:image/jpeg;base64,...)
